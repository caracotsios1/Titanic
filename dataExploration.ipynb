# %% [markdown]
# # dataExploration

# %%
train <- read.csv("Data/train.csv")

# %%
train
# Out:
#     PassengerId Survived Pclass
# 1    1          0        3
# 2    2          1        1
# 3    3          1        3
# 4    4          1        1
# 5    5          0        3
# 6    6          0        3
# 7    7          0        1
# 8    8          0        3
# 9    9          1        3
# 10  10          1        2
# 11  11          1        3
# 12  12          1        1
# 13  13          0        3
# 14  14          0        3
# 15  15          0        3
# 16  16          1        2
# 17  17          0        3
# 18  18          1        2
# 19  19          0        3
# 20  20          1        3
# 21  21          0        2
# 22  22          1        2
# 23  23          1        3
# 24  24          1        1
# 25  25          0        3
# 26  26          1        3
# 27  27          0        3
# 28  28          0        1
# 29  29          1        3
# 30  30          0        3
# ... ...         ...      ...
# 862 862         0        2
# 863 863         1        1
# ...

# %% [markdown]
# ## P Class

# %%
summary(train$Pclass)
hist(train$Pclass)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.000   2.000   3.000   2.309   3.000   3.000
# Plot with title "Histogram of train$Pclass"

# %% [markdown]
# ## Age

# %%
summary(train$Age)
hist(train$Age,
    main = "Passenger Age",
    xlab = "Age")
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    0.42   20.12   28.00   29.70   38.00   80.00     177
# Plot with title "Passenger Age"

# %% [markdown]
# ## SipSp

# %%
summary(train$SipSp)
hist(train$SipSp,
    main = "WTF is SipSP",
    xlab = "SipSP")

# %% [markdown]
# ## Parch

# %%
summary(train$Parch)
hist(train$Parch,
    main = "WTF is Parch",
    xlab = "Parch")

# %% [markdown]
# ## Fare

# %%
summary(train$Fare)
hist(train$Fare,
    main = "Passenger Fare",
    xlab = "Fare Dollars")

# %% [markdown]
# ## Survived

# %%
table(train$Survived)
# Out:
#   0   1
# 549 342

# %% [markdown]
# ## Sex

# %%
table(train$Sex)
# Out:
# female   male
#    314    577

# %% [markdown]
# ## Embarked

# %%
table(train$Embarked)
# Out:
#       C   Q   S
#   2 168  77 644
